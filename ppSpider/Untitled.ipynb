# %%
print('hellow world')
# Out:
# hellow world

# %%
import pandas as pd

# %%
df = pd.read_csv('data/pp-list-majestic-10k.csv')

# %%
df.head()
# Out:
#                domain  alexa_rank  \
# 0       evergreen.edu        6661
# 1       evergreen.edu        6661
# 2       abduzeedo.com        9040
# 3       abduzeedo.com        9040
# 4  marijuanabreak.com        4492
#
#                                               pp_url  \
# 0                https://evergreen.edu/about/privacy
# 1                https://evergreen.edu/about/privacy
# 2  https://abduzeedo.com/terms-service-and-privac...
# 3  https://abduzeedo.com/terms-service-and-privac...
# 4      https://www.marijuanabreak.com/privacy-policy
#
#                                            link_text
# 0                                     Privacy Policy
# 1                                     Privacy Policy
# 2  Terms of Service, Copyright Claims, and Privac...
# 3  Terms of Service, Copyright Claims, and Privac...
# 4                                     Privacy Policy

# %%
df1=df.set_index('domain')

# %%
df1
# Out:
#                     alexa_rank  \
# domain
# evergreen.edu             6661
# evergreen.edu             6661
# abduzeedo.com             9040
# abduzeedo.com             9040
# marijuanabreak.com        4492
# ...                        ...
# firefox.com.cn            3663
# firefox.com.cn            3663
# firefox.com.cn            3663
# padi.com                  7605
# padi.com                  7605
#
#                                                                pp_url  \
# domain
# evergreen.edu                     https://evergreen.edu/about/privacy
# evergreen.edu                     https://evergreen.edu/about/privacy
# abduzeedo.com       https://abduzeedo.com/terms-service-and-privac...
# abduzeedo.com       https://abduzeedo.com/terms-service-and-privac...
# marijuanabreak.com      https://www.marijuanabreak.com/privacy-policy
# ...                                                               ...
# firefox.com.cn              https://www.mozilla.org/privacy/websites/
# ...

# %%
df1['alexa_rank']
# Out:
# domain
# evergreen.edu         6661
# evergreen.edu         6661
# abduzeedo.com         9040
# abduzeedo.com         9040
# marijuanabreak.com    4492
#                       ...
# firefox.com.cn        3663
# firefox.com.cn        3663
# firefox.com.cn        3663
# padi.com              7605
# padi.com              7605
# Name: alexa_rank, Length: 13317, dtype: int64

# %% [markdown]
# # df1.loc['padi.com']

# %%
df1.sort_index(inplace=True)

# %%
df1
# Out:
#                    alexa_rank  \
# domain
# 000webhost.com            807
# 000webhost.com            807
# 000webhostapp.com         670
# 000webhostapp.com         670
# 0catch.com               9264
# ...                       ...
# zyxel.com                9583
# zyxel.com                9583
# zyxel.com                9583
# zzz.com.ua               7229
# zzz.com.ua               7229
#
#                                                               pp_url  \
# domain
# 000webhost.com                    https://www.000webhost.com/privacy
# 000webhost.com                    https://www.000webhost.com/privacy
# 000webhostapp.com                 https://www.000webhost.com/privacy
# 000webhostapp.com                 https://www.000webhost.com/privacy
# 0catch.com                            http://info.0catch.com/privacy
# ...                                                              ...
# zyxel.com           https://www.zyxel.com/it/it/privacy_policy.shtml
# ...

# %%
df1.loc[df1['alexa_rank'] < 10]
# Out:
#              alexa_rank                                            pp_url  \
# domain
# apple.com             8              https://www.apple.com/legal/privacy/
# apple.com             8                    https://www.apple.com/privacy/
# apple.com             8                    https://www.apple.com/privacy/
# apple.com             8              https://www.apple.com/legal/privacy/
# youtube.com           3  https://www.google.com/intl/en/policies/privacy/
# youtube.com           3  https://www.google.com/intl/en/policies/privacy/
#
#                   link_text
# domain
# apple.com    Privacy Policy
# apple.com           Privacy
# apple.com           Privacy
# apple.com    Privacy Policy
# youtube.com         Privacy
# youtube.com         Privacy
